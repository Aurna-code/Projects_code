# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mldlpy3

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
import pydotplus
from sklearn import tree

# %%
ah = pd.read_csv('data/2019agehouse1.csv', encoding='euc-kr')

# %%
plt.rc('font', family='NanumGothic')
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus']=False

# %%
ah
# Out:
#      0~10    10대     20대     30대     40대     50대    60대    70대      1인     2인  \
# 0    8757  12890   28564   22634   24706   26951  19231  12606   24671  16208
# 1    8039   8107   21607   22519   20207   22652  17157  10262   22078  14578
# 2   15817  18087   35759   42338   40089   38507  27616  17180   35148  25164
# 3   22883  23146   49939   54022   49671   50610  35106  20201   41488  32125
# 4   23494  29562   67229   62381   57636   59566  40075  21579   58714  35678
# 5   22908  27139   64520   54171   54344   56644  44039  27594   58152  36060
# 6   26124  30280   58365   62697   61822   73089  53462  29641   52196  44057
# 7   31479  40748   71274   63691   74027   69896  51558  32653   57832  44443
# 8   18464  24962   44801   43513   50618   54854  43389  29061   42791  35439
# 9   21782  29220   46441   45463   52970   59780  45917  26596   32653  36329
# 10  37560  59911   77922   71061   93093   89973  63098  35612   53365  52832
# ...

# %%
ah.describe()
# Out:
#                0~10           10대            20대            30대  \
# count     25.000000     25.000000      25.000000      25.000000
# mean   27846.960000  34319.000000   61223.960000   63720.480000
# std    10849.669601  14846.926205   20200.947044   22691.338405
# min     8039.000000   8107.000000   21607.000000   22519.000000
# 25%    21782.000000  26187.000000   49939.000000   47422.000000
# 50%    27571.000000  31107.000000   58746.000000   63691.000000
# 75%    33345.000000  42567.000000   71160.000000   71646.000000
# max    55335.000000  63748.000000  109842.000000  117981.000000
#
#                  40대            50대           60대           70대  \
# count      25.000000      25.000000     25.000000     25.000000
# mean    65172.800000   64534.280000  47006.720000  26761.280000
# std     22573.305189   19449.051486  14646.350793   7316.869267
# min     20207.000000   22652.000000  17157.000000  10262.000000
# 25%     50618.000000   54854.000000  37724.000000  24328.000000
# ...

# %%
ah.corr()
# Out:
#                0~10       10대       20대       30대       40대       50대  \
# 0~10       1.000000  0.927172  0.784363  0.921459  0.974377  0.935909
# 10대        0.927172  1.000000  0.723810  0.791376  0.964730  0.888352
# 20대        0.784363  0.723810  1.000000  0.911221  0.832625  0.829254
# 30대        0.921459  0.791376  0.911221  1.000000  0.915295  0.901304
# 40대        0.974377  0.964730  0.832625  0.915295  1.000000  0.950088
# 50대        0.935909  0.888352  0.829254  0.901304  0.950088  1.000000
# 60대        0.920409  0.856764  0.837972  0.901532  0.930207  0.985779
# 70대        0.806459  0.772739  0.844698  0.817759  0.858728  0.901973
# 1인         0.510501  0.408394  0.904833  0.773993  0.577489  0.590383
# 2인         0.914229  0.844766  0.909062  0.946669  0.938434  0.959832
# 3인         0.972176  0.945005  0.825473  0.901368  0.980399  0.976480
# 4인         0.971630  0.973951  0.781365  0.863430  0.978845  0.954677
# ...

# %%
data = ah.iloc[:, 0:15]
target = ah.iloc[:, 15]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(data, target, test_size=0.3, stratify = target, random_state=2111121455)

# %%
knc = KNeighborsClassifier(n_neighbors = 1)
knc.fit(Xtrain, ytrain)
pred = knc.predict(Xtest)
knc.score(Xtrain, ytrain), accuracy_score(pred, ytest)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# (1.0, 0.375)

# %%
knc = KNeighborsClassifier(n_neighbors = 2)
knc.fit(Xtrain, ytrain)
pred = knc.predict(Xtest)
knc.score(Xtrain, ytrain), accuracy_score(pred, ytest)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# (0.8235294117647058, 0.25)

# %%
knc = KNeighborsClassifier(n_neighbors = 3)
knc.fit(Xtrain, ytrain)
pred = knc.predict(Xtest)
knc.score(Xtrain, ytrain), accuracy_score(pred, ytest)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# (0.7647058823529411, 0.625)

# %%
scores = []
for k in range(1, 30+1):
    knc = KNeighborsClassifier(n_neighbors = k)
    score = cross_val_score(knc, Xtrain, ytrain, cv=7, scoring='accuracy')
    scores.append(score.mean())

# %%
plt.plot(scores, 'ro-')

# %%
knc = KNeighborsClassifier(n_neighbors = 5)
knc.fit(Xtrain, ytrain)
pred = knc.predict(Xtest)
knc.score(Xtrain, ytrain), accuracy_score(pred,ytest)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# (0.7058823529411765, 0.375)

# %%
sns.scatterplot('STL', '2P', data=ah, hue='Pos')

# %%
knc = KNeighborsClassifier(n_neighbors = 10)
knc.fit(data, target)
knc.score(data, target)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/base.py:442: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# 0.56

# %%
dtclf = DecisionTreeClassifier(criterion='entropy', max_depth=4)
dtclf.fit(Xtrain, ytrain)
pred = dtclf.predict(Xtest)

# %%
accuracy_score(ytest, pred)
# Out:
# 0.75

# %%
dtclf = DecisionTreeClassifier(criterion='entropy', max_depth=3)
dtclf.fit(Xtrain, ytrain)
pred = dtclf.predict(Xtest)

# %%
accuracy_score(ytest, pred)
# Out:
# 0.625

# %%
dtclf = DecisionTreeClassifier(criterion='entropy', max_depth=4)
dtclf.fit(Xtrain, ytrain)
pred = dtclf.predict(Xtest)

# %%
accuracy_score(ytest, pred)
# Out:
# 0.625

# %% [markdown]
# ### 정확도 0.75

# %%
dot_data = tree.export_graphviz(dtclf, out_file=None)

# %%
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
graph.write_png('test4.png')
# Out:
# True

# %%
import matplotlib.image as pltimg

# %%
img = pltimg.imread('test4.png')

# %%
plt.figure(figsize=(21,12))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1190.5, 498.5, -0.5)

# %%
from matplotlib.colors import ListedColormap

# %%
cols = ['0~10','10대','20대','30대','40대','50대','60대','70대','1인','2인','3인','4인','5인','6인','7인']

# %%
dot_data = tree.export_graphviz(dtclf, out_file=None, feature_names=cols, class_names=['0','1','2'])
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png('test4.png')
# Out:
# True

# %%
img = plt.imread('test4.png')
plt.figure(figsize=(16,14))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1186.5, 580.5, -0.5)

# %% [markdown]
# #### 20대 평균 61224로 20대가 평균보다 적을 경우 재활용률이 상으로 분류됨
# + 그 중에선 7인 가구가 평균(310)보다 적고
#     - 4인 가구(24561) 평균보다 적을 경우 재활용률이 하일 가능성이 높음
#
# #### 20대가 평균보다 높을 경우
# + 10대 평균 34319로 10대가 평균보다 적을 경우 재활용률이 상으로 분류됨
#     - 여기서도 4인 가구가 평균보다 적을 경우 재활용률이 하로 분류됨

# %%
from scipy.stats import entropy

# %%
plot_decision_regions(Xtrain, ytrain, dtclf)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16668/1244810150.py in <module>
# ----> 1 plot_decision_regions(Xtrain, ytrain, dtclf)
#       2 plt.show()
#
# NameError: name 'plot_decision_regions' is not defined

# %%
data = ah.iloc[:, 0:12]
target = ah.iloc[:, 15]

# %%
data
# Out:
#      0~10    10대     20대     30대     40대     50대    60대    70대      1인     2인  \
# 0    8757  12890   28564   22634   24706   26951  19231  12606   24671  16208
# 1    8039   8107   21607   22519   20207   22652  17157  10262   22078  14578
# 2   15817  18087   35759   42338   40089   38507  27616  17180   35148  25164
# 3   22883  23146   49939   54022   49671   50610  35106  20201   41488  32125
# 4   23494  29562   67229   62381   57636   59566  40075  21579   58714  35678
# 5   22908  27139   64520   54171   54344   56644  44039  27594   58152  36060
# 6   26124  30280   58365   62697   61822   73089  53462  29641   52196  44057
# 7   31479  40748   71274   63691   74027   69896  51558  32653   57832  44443
# 8   18464  24962   44801   43513   50618   54854  43389  29061   42791  35439
# 9   21782  29220   46441   45463   52970   59780  45917  26596   32653  36329
# 10  37560  59911   77922   71061   93093   89973  63098  35612   53365  52832
# ...

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(data, target, test_size=0.3, stratify = target, random_state=2111121455)

# %%
dtc = DecisionTreeClassifier(criterion='gini', max_depth=3)
dtc.fit(data,target)
dtc.score(data, target)
# Out:
# 0.88

# %%
dot_data2 = tree.export_graphviz(dtc, out_file=None, feature_names=cols[:12], class_names=['0', '1', '2'])
graph2 = pydotplus.graph_from_dot_data(dot_data2)
graph2.write_png('test403.png')
# Out:
# True

# %%
img2 = plt.imread('test403.png')
plt.figure(figsize=(16,14))
plt.imshow(img2)
plt.axis('off')
# Out:
# (-0.5, 1203.5, 580.5, -0.5)

# %%
data = ah.iloc[:, 0:12]
target = ah.iloc[:, 15]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(data, target, test_size=0.3, stratify = target, random_state=2111121455)

# %%
dtc = DecisionTreeClassifier(criterion='gini', max_depth=3)
dtc.fit(data,target)
dtc.score(data, target)
# Out:
# 0.88

# %%
dot_data2 = tree.export_graphviz(dtc, out_file=None, feature_names=cols[:12], class_names=['0', '1', '2'])
graph2 = pydotplus.graph_from_dot_data(dot_data2)
graph2.write_png('test404.png')
# Out:
# True

# %%
img2 = plt.imread('test404.png')
plt.figure(figsize=(16,14))
plt.imshow(img2)
plt.axis('off')
# Out:
# (-0.5, 1207.5, 580.5, -0.5)

# %%
data = ah.iloc[:, 0:8]
target = ah.iloc[:, 15]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(data, target, test_size=0.3, stratify = target, random_state=2111121455)

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=3)
dtc.fit(data,target)
dtc.score(data, target)
# Out:
# 0.88

# %%
dot_data2 = tree.export_graphviz(dtc, out_file=None, feature_names=cols[:8], class_names=['0', '1', '2'])
graph2 = pydotplus.graph_from_dot_data(dot_data2)
graph2.write_png('test402.png')
# Out:
# True

# %%
img2 = plt.imread('test402.png')
plt.figure(figsize=(16,14))
plt.imshow(img2)
plt.axis('off')
# Out:
# (-0.5, 900.5, 580.5, -0.5)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter = 1000)
lr.fit(Xtrain,ytrain)
pred = lr.predict(Xtest)

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bayes = BernoulliNB()
bayes.fit(data,target)
bayes.score(data, target)
# Out:
# 0.6
