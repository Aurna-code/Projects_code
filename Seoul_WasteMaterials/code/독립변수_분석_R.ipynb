# %%
test1<-read.csv('data/testfin.csv', sep=',')

# %%
head(test1)
# Out:
#   아파트.계 다세대주택.계 연립주택.계 단독주택.계 X20대1인  X30대1인  X40대1인
# 1 0.335     0.117         0.268       0.262       0.2764500 0.1196552 0.1246584
# 2 0.618     0.046         0.174       0.141       0.2324919 0.1321764 0.1315190
# 3 0.505     0.053         0.243       0.189       0.2165071 0.1472303 0.1155609
# 4 0.740     0.022         0.111       0.115       0.2720911 0.1348362 0.1264530
# 5 0.358     0.045         0.410       0.171       0.2993371 0.1200302 0.1118281
# 6 0.628     0.032         0.159       0.165       0.3353303 0.1037341 0.1076898
#   X50대1인   X60대1인   생활폐기물재활용률 생활폐기물배출량
# 1 0.10672363 0.08340069 0.5085784          244.8
# 2 0.12038741 0.08445087 0.4188401          325.9
# 3 0.10053957 0.07540468 0.5452218          234.4
# 4 0.10931079 0.07683457 0.5986871          228.5
# 5 0.09113818 0.05746296 0.6629073          239.4
# 6 0.10732868 0.08347969 0.6457286          318.4

# %%
pairs(test1, panel=panel.smooth)
# Out:
# plot without title

# %%
install.packages('corrplot')
# Out:
# Installing package into ‘/home/hadoop/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)

# %%
library(corrplot)
# Out:
# corrplot 0.92 loaded

# %%
aum <- lm(생활폐기물배출량~., test1)
.opar <- par(no.readonly=T) 
par(mfrow=c(2,2))
plot(aum)
# Out:
# Plot with title “”

# %% [markdown]
# #### 선형성 : 빨간 선은 별로 직선에 가깝지 않아 정규분포도는 그리 높지 않음
# #### 정규성 : 가운데는 잔차가 직선에 붙어 있지만 양쪽 끝으로 갈수록 다소 멀어짐
# #### 분산성 : 선이 중간에서 굽어 있음. 그나마 분포는 위아래 균등한 편
# #### 독립성 : 0.5를 벗어나지는 않지만 이상치들의 영향이 있는 것으로 보임

# %%
summary(aum)
# Out:
# Call:
# lm(formula = 생활폐기물배출량 ~ ., data = test1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -61.256 -13.633   0.941  13.193  54.598
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         18383.9     3946.4   4.658 0.000369 ***
# 아파트.계          -17247.2     3796.4  -4.543 0.000460 ***
# 다세대주택.계      -15651.1     3629.3  -4.312 0.000716 ***
# 연립주택.계        -17414.6     3804.3  -4.578 0.000430 ***
# 단독주택.계        -18654.0     4062.1  -4.592 0.000419 ***
# X20대1인            -1995.3      583.9  -3.417 0.004168 **
# X30대1인            -1473.0     1329.0  -1.108 0.286400
# X40대1인            -3268.0     1618.7  -2.019 0.063074 .
# X50대1인            -1809.7     2615.6  -0.692 0.500326
# X60대1인              560.5     1759.6   0.319 0.754790
# 생활폐기물재활용률    599.9      143.2   4.190 0.000908 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 41.37 on 14 degrees of freedom
# Multiple R-squared:  0.8284,	Adjusted R-squared:  0.7059
# F-statistic: 6.761 on 10 and 14 DF,  p-value: 0.0007552

# %% [markdown]
# #### 의미있는 변수 : 아파트/계, 다세대주택/계, 연립주택/계, 단독주택/계, 20대1인가구/전체1인가구, 40대1인가구/전체1인가구, 생활폐기물재활용률

# %% [markdown]
# #### 모델의 결정력 - 조정된 R계수: 0.7059. 이 변수 모델은 0.75에는 미치지 못하지만 대략 전체의 70%정도는 설명할 수 있음
# #### P 밸류 - 0.0007552 < 0.05로 귀무가설 기각

# %%
step(lm(생활폐기물배출량~., data=test1), direction='backward')
# Out:
# Start:  AIC=193.63
# 생활폐기물배출량 ~ 아파트.계 + 다세대주택.계 +
#     연립주택.계 + 단독주택.계 + X20대1인 + X30대1인 +
#     X40대1인 + X50대1인 + X60대1인 + 생활폐기물재활용률
#
#                      Df Sum of Sq   RSS    AIC
# - X60대1인            1       174 24135 191.81
# - X50대1인            1       819 24781 192.47
# <none>                            23962 193.63
# - X30대1인            1      2102 26064 193.74
# - X40대1인            1      6976 30938 198.02
# - X20대1인            1     19986 43948 206.80
# - 생활폐기물재활용률  1     30051 54013 211.95
# - 다세대주택.계       1     31831 55792 212.76
# - 아파트.계           1     35325 59287 214.28
# - 연립주택.계         1     35865 59827 214.51
# - 단독주택.계         1     36093 60055 214.60
#
# Step:  AIC=191.81
# 생활폐기물배출량 ~ 아파트.계 + 다세대주택.계 +
#     연립주택.계 + 단독주택.계 + X20대1인 + X30대1인 +
#     X40대1인 + X50대1인 + 생활폐기물재활용률
#
#                      Df Sum of Sq   RSS    AIC
# - X50대1인            1      1563 25698 191.38
# - X30대1인            1      1930 26065 191.74
# <none>                            24135 191.81
# - X40대1인            1     13096 37232 200.65
# - X20대1인            1     21142 45277 205.54
# - 다세대주택.계       1     33478 57614 211.57
# - 생활폐기물재활용률  1     34226 58361 211.89
# - 아파트.계           1     37245 61381 213.15
# - 연립주택.계         1     37742 61878 213.35
# - 단독주택.계         1     38751 62887 213.75
#
# Step:  AIC=191.38
# 생활폐기물배출량 ~ 아파트.계 + 다세대주택.계 +
#     연립주택.계 + 단독주택.계 + X20대1인 + X30대1인 +
#     X40대1인 + 생활폐기물재활용률
#
#                      Df Sum of Sq   RSS    AIC
# - X30대1인            1       606 26305 189.97
# <none>                            25698 191.38
# - X20대1인            1     20161 45860 203.86
# - X40대1인            1     31136 56835 209.23
# - 생활폐기물재활용률  1     34293 59991 210.58
# - 다세대주택.계       1     34660 60359 210.73
# - 아파트.계           1     38062 63761 212.10
# - 연립주택.계         1     38435 64133 212.25
# - 단독주택.계         1     39060 64759 212.49
#
# Step:  AIC=189.97
# 생활폐기물배출량 ~ 아파트.계 + 다세대주택.계 +
#     연립주택.계 + 단독주택.계 + X20대1인 + X40대1인 +
#     생활폐기물재활용률
#
#                      Df Sum of Sq   RSS    AIC
# <none>                            26305 189.97
# - X20대1인            1     33192 59497 208.37
# - 생활폐기물재활용률  1     33702 60007 208.58
# - X40대1인            1     38916 65221 210.67
# - 다세대주택.계       1     39957 66262 211.06
# - 아파트.계           1     46082 72386 213.27
# - 연립주택.계         1     46894 73199 213.55
# - 단독주택.계         1     47145 73449 213.64
# Call:
# lm(formula = 생활폐기물배출량 ~ 아파트.계 + 다세대주택.계 +
#     연립주택.계 + 단독주택.계 + X20대1인 + X40대1인 +
#     생활폐기물재활용률, data = test1)
#
# Coefficients:
#        (Intercept)           아파트.계       다세대주택.계         연립주택.계
#            16666.0            -15906.7            -14522.4            -16038.4
#        단독주택.계            X20대1인            X40대1인  생활폐기물재활용률
#           -17094.0             -1493.4             -3997.5               572.6

# %% [markdown]
# #### 후진제거법 적용 결과 - Summary 기술통계함수로 나온 변수와 일치

# %%
apt <- test1$아파트.계
multi <- test1$다세대주택.계
row <- test1$연립주택.계
house <- test1$단독주택.계
twenty <- test1$X20대1인
forty <- test1$X40대1인
repercent <- test1$생활폐기물재활용률
trash <- test1$생활폐기물배출량
test2 <- data.frame(apt, multi, row, house, twenty, forty, repercent, trash)

# %%
test2
# Out:
#    apt   multi row   house twenty    forty      repercent trash
# 1  0.335 0.117 0.268 0.262 0.2764500 0.12465843 0.5085784 244.8
# 2  0.618 0.046 0.174 0.141 0.2324919 0.13151898 0.4188401 325.9
# 3  0.505 0.053 0.243 0.189 0.2165071 0.11556086 0.5452218 234.4
# 4  0.740 0.022 0.111 0.115 0.2720911 0.12645298 0.5986871 228.5
# 5  0.358 0.045 0.410 0.171 0.2993371 0.11182806 0.6629073 239.4
# 6  0.628 0.032 0.159 0.165 0.3353303 0.10768978 0.6457286 318.4
# 7  0.494 0.040 0.287 0.165 0.1351117 0.17745782 0.6339468 293.4
# 8  0.571 0.045 0.211 0.162 0.3251341 0.10603154 0.6535119 276.2
# 9  0.356 0.049 0.404 0.180 0.1562220 0.15889242 0.5726351 177.6
# 10 0.607 0.039 0.267 0.081 0.1135478 0.16526201 0.5299016 264.2
# 11 0.864 0.018 0.079 0.035 0.1835111 0.13416492 0.4284971 192.3
# 12 0.395 0.039 0.459 0.099 0.1581422 0.13333794 0.5113598 294.9
# 13 0.536 0.054 0.276 0.125 0.3364619 0.09477970 0.4497354 170.1
# 14 0.575 0.026 0.291 0.095 0.2983442 0.08383461 0.4589099 354.1
# 15 0.631 0.028 0.281 0.054 0.1140075 0.15338777 0.4657412 223.3
# 16 0.582 0.025 0.335 0.053 0.2054960 0.11227545 0.6511840 439.2
# 17 0.627 0.056 0.224 0.086 0.1921289 0.13411548 0.3227352 229.6
# 18 0.461 0.057 0.347 0.128 0.1889970 0.14893466 0.6043711 224.2
# 19 0.698 0.014 0.144 0.133 0.2348594 0.10784375 0.4238259 261.9
# 20 0.533 0.046 0.286 0.126 0.3290588 0.08703452 0.5930755 222.4
# 21 0.434 0.049 0.335 0.167 0.3712519 0.07679927 0.6461852 343.4
# 22 0.708 0.040 0.202 0.041 0.2047699 0.11217059 0.3572548 319.1
# 23 0.725 0.034 0.191 0.040 0.2026261 0.09695793 0.4807692 468.0
# 24 0.601 0.023 0.330 0.038 0.1853611 0.11572177 0.4831004 393.5
# 25 0.632 0.023 0.265 0.072 0.1499722 0.14345337 0.5474694 302.3

# %%
library(car)

# %%
aum2 <- lm(trash~., test2)
.opar <- par(no.readonly=T) 
par(mfrow=c(2,2))
plot(aum2)
# Out:
# Plot with title “”

# %%
round(vif(aum2),2)
# Out:
#       apt     multi       row     house    twenty     forty repercent
#   2268.83     51.92   1138.94    502.99      9.21      6.63      2.23

# %% [markdown]
# #### 다중공선성의 경우 주택형태들이 너무 높은 상관성을 보이는 반면 그 외 변수는 상대적으로 덜함

# %%
cor(test2)
# Out:
#           apt         multi       row         house       twenty
# apt        1.00000000 -0.64534464 -0.82088605 -0.69183777 -0.161195334
# multi     -0.64534464  1.00000000  0.24749726  0.68324193  0.223961528
# row       -0.82088605  0.24749726  1.00000000  0.17016853 -0.123215938
# house     -0.69183777  0.68324193  0.17016853  1.00000000  0.445992589
# twenty    -0.16119533  0.22396153 -0.12321594  0.44599259  1.000000000
# forty     -0.05840589  0.02391369  0.10385830 -0.02744226 -0.820323726
# repercent -0.44879842  0.03019716  0.34788570  0.43068073  0.293014178
# trash      0.18269371 -0.28149661  0.02979215 -0.36864684 -0.004387196
#           forty       repercent   trash
# apt       -0.05840589 -0.44879842  0.182693706
# multi      0.02391369  0.03019716 -0.281496608
# row        0.10385830  0.34788570  0.029792154
# house     -0.02744226  0.43068073 -0.368646841
# twenty    -0.82032373  0.29301418 -0.004387196
# forty      1.00000000 -0.01867946 -0.326452744
# repercent -0.01867946  1.00000000  0.073944204
# trash     -0.32645274  0.07394420  1.000000000
